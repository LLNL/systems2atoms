# %% [markdown]
# ## Plot (a) catalyst amount, (b) catalyst purchase cost, (c) total refueling station cost vs. dehydrogenation temperature and pressure for multiple catalysts

# %% [markdown]
# ### IMPORT MODULES

# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# update plot formatting
mpl.rcParams.update({'font.size': 14})
mpl.rcParams.update({'mathtext.default': 'rm'})
mpl.rcParams.update({'font.family': 'sans-serif'})
mpl.rcParams.update({'font.sans-serif': 'Calibri'})

# %% [markdown]
# ### USER INPUT

# %%
# output folder to read from
folder = 'outputs 2024-05-03 multi catal'

# %%
# user-defined input parameter names for plots
input_params_varied_user = [
    'scenario', 
    'dehydr. reaction temperature (K)', 
    'dehydr. reaction pressure (bar)',
    ]

# %% [markdown]
# ### READ INPUT PARAMETERS

# %%
# read input parameter map
df_input_params = pd.read_csv(
    os.path.join('..\outputs', folder, 'input params.csv'),
    index_col = 'run #'
    )

# drop "default" results
df_input_params = df_input_params.loc[df_input_params.index != 0]

# extract output dollar year
output_dollar_year = df_input_params['output dollar year'].values[0]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\yuan13\AppData\Local\Temp\ipykernel_20196\379060210.py:3: SyntaxWarning: invalid escape sequence '\o'
#   os.path.join('..\outputs', folder, 'input params.csv'),

# %%
# extract catalyst unit costs ($/kg)
df_catal_unit_cost = df_input_params[[
    'scenario', 
    'dehydr. catalyst cost ($/kg)'
]].drop_duplicates()

# rename scenario (catalyst name)
df_catal_unit_cost['scenario'] = \
    df_catal_unit_cost['scenario'].str.strip(' 4nm')

# set index
df_catal_unit_cost.set_index(
    'scenario',
    inplace=True
)

df_catal_unit_cost
# Out:
#           dehydr. catalyst cost ($/kg)
# scenario
# Pd                              3500.0
# Pt                              3000.0
# Cu                              1400.0

# %%
# read varied input parameters
df_input_params_varied_all = pd.read_csv(
    os.path.join('..\outputs', folder, 'input params_varied.csv'), 
    index_col = 'run #'
    )
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\yuan13\AppData\Local\Temp\ipykernel_20196\3716109635.py:3: SyntaxWarning: invalid escape sequence '\o'
#   os.path.join('..\outputs', folder, 'input params_varied.csv'),

# %%
# create dataframe of input parameters to plot
df_input_params_varied_plot = df_input_params_varied_all.copy()

# use user-defined input parameters for plots if not empty
if input_params_varied_user:
    df_input_params_varied_plot = \
        df_input_params_varied_all[input_params_varied_user]
    
df_input_params_varied_plot
# Out:
#        scenario  dehydr. reaction temperature (K)  \
# run #
# 0      baseline                        300.000000
# 1        Pd 4nm                        300.000000
# 2        Pd 4nm                        310.526316
# 3        Pd 4nm                        321.052632
# 4        Pd 4nm                        331.578947
# 5        Pd 4nm                        342.105263
# 6        Pd 4nm                        352.631579
# 7        Pd 4nm                        363.157895
# 8        Pd 4nm                        373.684211
# 9        Pd 4nm                        384.210526
# 10       Pd 4nm                        300.000000
# 11       Pd 4nm                        310.526316
# 12       Pd 4nm                        321.052632
# 13       Pd 4nm                        331.578947
# 14       Pd 4nm                        342.105263
# 15       Pd 4nm                        352.631579
# 16       Pd 4nm                        363.157895
# 17       Pd 4nm                        373.684211
# 18       Pd 4nm                        384.210526
# 19       Pt 4nm                        300.000000
# 20       Pt 4nm                        310.526316
# 21       Pt 4nm                        321.052632
# 22       Pt 4nm                        331.578947
# 23       Pt 4nm                        342.105263
# 24       Pt 4nm                        352.631579
# 25       Pt 4nm                        363.157895
# 26       Pt 4nm                        373.684211
# 27       Pt 4nm                        384.210526
# 28       Pt 4nm                        300.000000
# 29       Pt 4nm                        310.526316
# 30       Pt 4nm                        321.052632
# 31       Pt 4nm                        331.578947
# 32       Pt 4nm                        342.105263
# 33       Pt 4nm                        352.631579
# 34       Pt 4nm                        363.157895
# 35       Pt 4nm                        373.684211
# 36       Pt 4nm                        384.210526
# 37       Cu 4nm                        300.000000
# 38       Cu 4nm                        310.526316
# 39       Cu 4nm                        321.052632
# 40       Cu 4nm                        331.578947
# 41       Cu 4nm                        342.105263
# 42       Cu 4nm                        352.631579
# 43       Cu 4nm                        363.157895
# 44       Cu 4nm                        373.684211
# 45       Cu 4nm                        384.210526
# 46       Cu 4nm                        300.000000
# 47       Cu 4nm                        310.526316
# 48       Cu 4nm                        321.052632
# 49       Cu 4nm                        331.578947
# 50       Cu 4nm                        342.105263
# 51       Cu 4nm                        352.631579
# 52       Cu 4nm                        363.157895
# 53       Cu 4nm                        373.684211
# 54       Cu 4nm                        384.210526
#
#        dehydr. reaction pressure (bar)
# run #
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
# 5                                  1.0
# 6                                  1.0
# 7                                  1.0
# 8                                  1.0
# 9                                  1.0
# 10                               100.0
# 11                               100.0
# 12                               100.0
# 13                               100.0
# 14                               100.0
# 15                               100.0
# 16                               100.0
# 17                               100.0
# 18                               100.0
# 19                                 1.0
# 20                                 1.0
# 21                                 1.0
# 22                                 1.0
# 23                                 1.0
# 24                                 1.0
# 25                                 1.0
# 26                                 1.0
# 27                                 1.0
# 28                               100.0
# 29                               100.0
# 30                               100.0
# 31                               100.0
# 32                               100.0
# 33                               100.0
# 34                               100.0
# 35                               100.0
# 36                               100.0
# 37                                 1.0
# 38                                 1.0
# 39                                 1.0
# 40                                 1.0
# 41                                 1.0
# 42                                 1.0
# 43                                 1.0
# 44                                 1.0
# 45                                 1.0
# 46                               100.0
# 47                               100.0
# 48                               100.0
# 49                               100.0
# 50                               100.0
# 51                               100.0
# 52                               100.0
# 53                               100.0
# 54                               100.0

# %% [markdown]
# ### DATA PROCESSING: total refueling station cost

# %%
# read csv
f = 'output_all runs_refueling station costs.csv'
df_stn = pd.read_csv(
    os.path.join('..\outputs', folder, f), 
    index_col = 'run #'
    )

# merge in varied input parameters
df_stn = df_input_params_varied_plot.merge(
    right = df_stn, 
    on='run #', 
    how = 'right'
    )

# drop "default" results
df_stn = df_stn.loc[df_stn.index != 0]

df_stn
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\o'
# <>:4: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\yuan13\AppData\Local\Temp\ipykernel_20196\2840545103.py:4: SyntaxWarning: invalid escape sequence '\o'
#   os.path.join('..\outputs', folder, f),
#       scenario  dehydr. reaction temperature (K)  \
# run #
# 1       Pd 4nm                        300.000000
# 1       Pd 4nm                        300.000000
# 1       Pd 4nm                        300.000000
# 1       Pd 4nm                        300.000000
# 1       Pd 4nm                        300.000000
# ...        ...                               ...
# 54      Cu 4nm                        384.210526
# 54      Cu 4nm                        384.210526
# 54      Cu 4nm                        384.210526
# 54      Cu 4nm                        384.210526
# 54      Cu 4nm                        384.210526
#
#        dehydr. reaction pressure (bar)             pathway         process  \
# run #
# 1                                  1.0                 all             all
# 1                                  1.0                 all             all
# 1                                  1.0  LOHC - formic acid  reconditioning
# 1                                  1.0  LOHC - formic acid  reconditioning
# 1                                  1.0  LOHC - formic acid  reconditioning
# ...                                ...                 ...             ...
# 54                               100.0  LOHC - formic acid  reconditioning
# 54                               100.0  LOHC - formic acid  reconditioning
# 54                               100.0  LOHC - formic acid  reconditioning
# 54                               100.0  LOHC - formic acid  reconditioning
# 54                               100.0  LOHC - formic acid  reconditioning
#
#                 location function        equipment   variable group  \
# run #
# 1                    all      all              all  input parameter
# 1                    all      all              all  input parameter
# 1      refueling station  pumping     reactor pump      energy cost
# 1      refueling station  pumping     reactor pump      energy cost
# 1      refueling station  pumping     reactor pump         O&M cost
# ...                  ...      ...              ...              ...
# 54     refueling station  cooling     refrigerator     capital cost
# 54     refueling station  storage   liquid storage     capital cost
# 54     refueling station  storage   liquid storage     capital cost
# 54     refueling station  storage  cascade storage     capital cost
# 54     refueling station  storage  cascade storage     capital cost
#
#                               variable name     unit         value
# run #
# 1                    dehydr. reactor volume      m^3  7.310286e-02
# 1                   dehydr. catalyst amount       kg  9.646712e+00
# 1                          electricity cost     $/yr  0.000000e+00
# 1                          electricity cost  $/kg H2  0.000000e+00
# 1      operation, maintenance, repair costs     $/yr  0.000000e+00
# ...                                     ...      ...           ...
# 54                   levelized capital cost  $/kg H2  8.786406e-02
# 54                   levelized capital cost     $/yr  6.718135e+04
# 54                   levelized capital cost  $/kg H2  1.840585e-02
# 54                   levelized capital cost     $/yr  1.202355e+06
# 54                   levelized capital cost  $/kg H2  3.294124e-01
#
# [4536 rows x 12 columns]

# %%
# filter results by units
df_stn_usd_per_kg = df_stn.loc[df_stn['unit'] == '$/kg H2'].copy()

# %%
# calculate total refueling station costs 
# as a function of temperature and pressure
df_stn_tot = df_stn_usd_per_kg.groupby(
    by = df_input_params_varied_plot.columns.tolist()
    )['value'].sum().reset_index()

# rename columns
df_stn_tot.rename(
    columns = {
        'value' : '$/kg H2'
        }, 
    inplace = True
    )

# convert temperature to deg.C
df_stn_tot['dehydr. reaction temperature (C)'] = \
    df_stn_tot['dehydr. reaction temperature (K)'] - 273.15

df_stn_tot
# Out:
#    scenario  dehydr. reaction temperature (K)  \
# 0    Cu 4nm                        300.000000
# 1    Cu 4nm                        300.000000
# 2    Cu 4nm                        310.526316
# 3    Cu 4nm                        310.526316
# 4    Cu 4nm                        321.052632
# 5    Cu 4nm                        321.052632
# 6    Cu 4nm                        331.578947
# 7    Cu 4nm                        331.578947
# 8    Cu 4nm                        342.105263
# 9    Cu 4nm                        342.105263
# 10   Cu 4nm                        352.631579
# 11   Cu 4nm                        352.631579
# 12   Cu 4nm                        363.157895
# 13   Cu 4nm                        363.157895
# 14   Cu 4nm                        373.684211
# 15   Cu 4nm                        373.684211
# 16   Cu 4nm                        384.210526
# 17   Cu 4nm                        384.210526
# 18   Pd 4nm                        300.000000
# 19   Pd 4nm                        300.000000
# 20   Pd 4nm                        310.526316
# 21   Pd 4nm                        310.526316
# 22   Pd 4nm                        321.052632
# 23   Pd 4nm                        321.052632
# 24   Pd 4nm                        331.578947
# 25   Pd 4nm                        331.578947
# 26   Pd 4nm                        342.105263
# 27   Pd 4nm                        342.105263
# 28   Pd 4nm                        352.631579
# 29   Pd 4nm                        352.631579
# 30   Pd 4nm                        363.157895
# 31   Pd 4nm                        363.157895
# 32   Pd 4nm                        373.684211
# 33   Pd 4nm                        373.684211
# 34   Pd 4nm                        384.210526
# 35   Pd 4nm                        384.210526
# 36   Pt 4nm                        300.000000
# 37   Pt 4nm                        300.000000
# 38   Pt 4nm                        310.526316
# 39   Pt 4nm                        310.526316
# 40   Pt 4nm                        321.052632
# 41   Pt 4nm                        321.052632
# 42   Pt 4nm                        331.578947
# 43   Pt 4nm                        331.578947
# 44   Pt 4nm                        342.105263
# 45   Pt 4nm                        342.105263
# 46   Pt 4nm                        352.631579
# 47   Pt 4nm                        352.631579
# 48   Pt 4nm                        363.157895
# 49   Pt 4nm                        363.157895
# 50   Pt 4nm                        373.684211
# 51   Pt 4nm                        373.684211
# 52   Pt 4nm                        384.210526
# 53   Pt 4nm                        384.210526
#
#     dehydr. reaction pressure (bar)    $/kg H2  \
# 0                               1.0   7.118231
# 1                             100.0   4.364424
# 2                               1.0   6.738462
# 3                             100.0   4.333959
# 4                               1.0   6.557565
# 5                             100.0   4.326265
# 6                               1.0   6.413009
# 7                             100.0   4.323122
# 8                               1.0   6.290325
# 9                             100.0   4.325120
# 10                              1.0   6.205566
# 11                            100.0   4.329323
# 12                              1.0   6.162024
# 13                            100.0   4.335729
# 14                              1.0   6.133172
# 15                            100.0   4.342134
# 16                              1.0   6.104320
# 17                            100.0   4.349128
# 18                              1.0   6.087458
# 19                            100.0   4.424435
# 20                              1.0   6.017401
# 21                            100.0   4.349880
# 22                              1.0   5.993979
# 23                            100.0   4.325348
# 24                              1.0   5.988519
# 25                            100.0   4.319764
# 26                              1.0   5.990425
# 27                            100.0   4.321743
# 28                              1.0   5.995490
# 29                            100.0   4.326918
# 30                              1.0   6.001987
# 31                            100.0   4.333489
# 32                              1.0   6.009164
# 33                            100.0   4.340702
# 34                              1.0   6.016672
# 35                            100.0   4.348236
# 36                              1.0  35.978488
# 37                            100.0  35.687572
# 38                              1.0  15.079462
# 39                            100.0  14.028416
# 40                              1.0   9.473211
# 41                            100.0   8.100808
# 42                              1.0   7.571838
# 43                            100.0   5.753934
# 44                              1.0   6.698992
# 45                            100.0   4.884856
# 46                              1.0   6.323127
# 47                            100.0   4.560307
# 48                              1.0   6.157843
# 49                            100.0   4.440674
# 50                              1.0   6.090158
# 51                            100.0   4.391879
# 52                              1.0   6.063401
# 53                            100.0   4.374567
#
#     dehydr. reaction temperature (C)
# 0                          26.850000
# 1                          26.850000
# 2                          37.376316
# 3                          37.376316
# 4                          47.902632
# 5                          47.902632
# 6                          58.428947
# 7                          58.428947
# 8                          68.955263
# 9                          68.955263
# 10                         79.481579
# 11                         79.481579
# 12                         90.007895
# 13                         90.007895
# 14                        100.534211
# 15                        100.534211
# 16                        111.060526
# 17                        111.060526
# 18                         26.850000
# 19                         26.850000
# 20                         37.376316
# 21                         37.376316
# 22                         47.902632
# 23                         47.902632
# 24                         58.428947
# 25                         58.428947
# 26                         68.955263
# 27                         68.955263
# 28                         79.481579
# 29                         79.481579
# 30                         90.007895
# 31                         90.007895
# 32                        100.534211
# 33                        100.534211
# 34                        111.060526
# 35                        111.060526
# 36                         26.850000
# 37                         26.850000
# 38                         37.376316
# 39                         37.376316
# 40                         47.902632
# 41                         47.902632
# 42                         58.428947
# 43                         58.428947
# 44                         68.955263
# 45                         68.955263
# 46                         79.481579
# 47                         79.481579
# 48                         90.007895
# 49                         90.007895
# 50                        100.534211
# 51                        100.534211
# 52                        111.060526
# 53                        111.060526

# %%
# dehydr. pressures to plot
dehydr_pres_bar_to_plot = [
    df_stn_tot['dehydr. reaction pressure (bar)'].min(),
    df_stn_tot['dehydr. reaction pressure (bar)'].max(),
    ]

dehydr_pres_bar_to_plot
# Out:
# [1.0, 100.0]

# %%
# filter total station cost results by pressure
df_stn_tot_pres = df_stn_tot.loc[
    df_stn_tot['dehydr. reaction pressure (bar)'].isin(
        dehydr_pres_bar_to_plot
        )
    ].copy()

# add column for temperature in deg.C
df_stn_tot_pres['dehydr. reaction temperature (C)'] = \
    df_stn_tot_pres['dehydr. reaction temperature (K)'] - 273.15

# drop column for temperature in K
df_stn_tot_pres.drop(
    columns = 'dehydr. reaction temperature (K)', 
    inplace = True
    )

# combine catalyst type and pressure columns
df_stn_tot_pres['catalyst, pressure'] = \
    df_stn_tot_pres['scenario'] + ', ' + \
    df_stn_tot_pres['dehydr. reaction pressure (bar)'].astype(int).astype(str) + \
    ' bar'

df_stn_tot_pres
# Out:
#    scenario  dehydr. reaction pressure (bar)    $/kg H2  \
# 0    Cu 4nm                              1.0   7.118231
# 1    Cu 4nm                            100.0   4.364424
# 2    Cu 4nm                              1.0   6.738462
# 3    Cu 4nm                            100.0   4.333959
# 4    Cu 4nm                              1.0   6.557565
# 5    Cu 4nm                            100.0   4.326265
# 6    Cu 4nm                              1.0   6.413009
# 7    Cu 4nm                            100.0   4.323122
# 8    Cu 4nm                              1.0   6.290325
# 9    Cu 4nm                            100.0   4.325120
# 10   Cu 4nm                              1.0   6.205566
# 11   Cu 4nm                            100.0   4.329323
# 12   Cu 4nm                              1.0   6.162024
# 13   Cu 4nm                            100.0   4.335729
# 14   Cu 4nm                              1.0   6.133172
# 15   Cu 4nm                            100.0   4.342134
# 16   Cu 4nm                              1.0   6.104320
# 17   Cu 4nm                            100.0   4.349128
# 18   Pd 4nm                              1.0   6.087458
# 19   Pd 4nm                            100.0   4.424435
# 20   Pd 4nm                              1.0   6.017401
# 21   Pd 4nm                            100.0   4.349880
# 22   Pd 4nm                              1.0   5.993979
# 23   Pd 4nm                            100.0   4.325348
# 24   Pd 4nm                              1.0   5.988519
# 25   Pd 4nm                            100.0   4.319764
# 26   Pd 4nm                              1.0   5.990425
# 27   Pd 4nm                            100.0   4.321743
# 28   Pd 4nm                              1.0   5.995490
# 29   Pd 4nm                            100.0   4.326918
# 30   Pd 4nm                              1.0   6.001987
# 31   Pd 4nm                            100.0   4.333489
# 32   Pd 4nm                              1.0   6.009164
# 33   Pd 4nm                            100.0   4.340702
# 34   Pd 4nm                              1.0   6.016672
# 35   Pd 4nm                            100.0   4.348236
# 36   Pt 4nm                              1.0  35.978488
# 37   Pt 4nm                            100.0  35.687572
# 38   Pt 4nm                              1.0  15.079462
# 39   Pt 4nm                            100.0  14.028416
# 40   Pt 4nm                              1.0   9.473211
# 41   Pt 4nm                            100.0   8.100808
# 42   Pt 4nm                              1.0   7.571838
# 43   Pt 4nm                            100.0   5.753934
# 44   Pt 4nm                              1.0   6.698992
# 45   Pt 4nm                            100.0   4.884856
# 46   Pt 4nm                              1.0   6.323127
# 47   Pt 4nm                            100.0   4.560307
# 48   Pt 4nm                              1.0   6.157843
# 49   Pt 4nm                            100.0   4.440674
# 50   Pt 4nm                              1.0   6.090158
# 51   Pt 4nm                            100.0   4.391879
# 52   Pt 4nm                              1.0   6.063401
# 53   Pt 4nm                            100.0   4.374567
#
#     dehydr. reaction temperature (C) catalyst, pressure
# 0                          26.850000      Cu 4nm, 1 bar
# 1                          26.850000    Cu 4nm, 100 bar
# 2                          37.376316      Cu 4nm, 1 bar
# 3                          37.376316    Cu 4nm, 100 bar
# 4                          47.902632      Cu 4nm, 1 bar
# 5                          47.902632    Cu 4nm, 100 bar
# 6                          58.428947      Cu 4nm, 1 bar
# 7                          58.428947    Cu 4nm, 100 bar
# 8                          68.955263      Cu 4nm, 1 bar
# 9                          68.955263    Cu 4nm, 100 bar
# 10                         79.481579      Cu 4nm, 1 bar
# 11                         79.481579    Cu 4nm, 100 bar
# 12                         90.007895      Cu 4nm, 1 bar
# 13                         90.007895    Cu 4nm, 100 bar
# 14                        100.534211      Cu 4nm, 1 bar
# 15                        100.534211    Cu 4nm, 100 bar
# 16                        111.060526      Cu 4nm, 1 bar
# 17                        111.060526    Cu 4nm, 100 bar
# 18                         26.850000      Pd 4nm, 1 bar
# 19                         26.850000    Pd 4nm, 100 bar
# 20                         37.376316      Pd 4nm, 1 bar
# 21                         37.376316    Pd 4nm, 100 bar
# 22                         47.902632      Pd 4nm, 1 bar
# 23                         47.902632    Pd 4nm, 100 bar
# 24                         58.428947      Pd 4nm, 1 bar
# 25                         58.428947    Pd 4nm, 100 bar
# 26                         68.955263      Pd 4nm, 1 bar
# 27                         68.955263    Pd 4nm, 100 bar
# 28                         79.481579      Pd 4nm, 1 bar
# 29                         79.481579    Pd 4nm, 100 bar
# 30                         90.007895      Pd 4nm, 1 bar
# 31                         90.007895    Pd 4nm, 100 bar
# 32                        100.534211      Pd 4nm, 1 bar
# 33                        100.534211    Pd 4nm, 100 bar
# 34                        111.060526      Pd 4nm, 1 bar
# 35                        111.060526    Pd 4nm, 100 bar
# 36                         26.850000      Pt 4nm, 1 bar
# 37                         26.850000    Pt 4nm, 100 bar
# 38                         37.376316      Pt 4nm, 1 bar
# 39                         37.376316    Pt 4nm, 100 bar
# 40                         47.902632      Pt 4nm, 1 bar
# 41                         47.902632    Pt 4nm, 100 bar
# 42                         58.428947      Pt 4nm, 1 bar
# 43                         58.428947    Pt 4nm, 100 bar
# 44                         68.955263      Pt 4nm, 1 bar
# 45                         68.955263    Pt 4nm, 100 bar
# 46                         79.481579      Pt 4nm, 1 bar
# 47                         79.481579    Pt 4nm, 100 bar
# 48                         90.007895      Pt 4nm, 1 bar
# 49                         90.007895    Pt 4nm, 100 bar
# 50                        100.534211      Pt 4nm, 1 bar
# 51                        100.534211    Pt 4nm, 100 bar
# 52                        111.060526      Pt 4nm, 1 bar
# 53                        111.060526    Pt 4nm, 100 bar

# %%
# pivot total station cost dataframe
df_stn_tot_pivot = df_stn_tot_pres.pivot(
    columns = ['catalyst, pressure'],
    index = 'dehydr. reaction temperature (C)',
    values = '$/kg H2'
    )

df_stn_tot_pivot
# Out:
# catalyst, pressure                Cu 4nm, 1 bar  Cu 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                              7.118231         4.364424
# 37.376316                              6.738462         4.333959
# 47.902632                              6.557565         4.326265
# 58.428947                              6.413009         4.323122
# 68.955263                              6.290325         4.325120
# 79.481579                              6.205566         4.329323
# 90.007895                              6.162024         4.335729
# 100.534211                             6.133172         4.342134
# 111.060526                             6.104320         4.349128
#
# catalyst, pressure                Pd 4nm, 1 bar  Pd 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                              6.087458         4.424435
# 37.376316                              6.017401         4.349880
# 47.902632                              5.993979         4.325348
# 58.428947                              5.988519         4.319764
# 68.955263                              5.990425         4.321743
# 79.481579                              5.995490         4.326918
# 90.007895                              6.001987         4.333489
# 100.534211                             6.009164         4.340702
# 111.060526                             6.016672         4.348236
#
# catalyst, pressure                Pt 4nm, 1 bar  Pt 4nm, 100 bar
# dehydr. reaction temperature (C)
# 26.850000                             35.978488        35.687572
# 37.376316                             15.079462        14.028416
# 47.902632                              9.473211         8.100808
# 58.428947                              7.571838         5.753934
# 68.955263                              6.698992         4.884856
# 79.481579                              6.323127         4.560307
# 90.007895                              6.157843         4.440674
# 100.534211                             6.090158         4.391879
# 111.060526                             6.063401         4.374567

# %% [markdown]
# ### DATA PROCESSING: catalyst amount

# %%
# filter for catalyst amount (inputs)
# kg = unit of catalyst amount
df_catal_amt_kg = df_stn.loc[
    df_stn['unit'] == 'kg'
    ].copy()

df_catal_amt_kg
# Out:
#       scenario  dehydr. reaction temperature (K)  \
# run #
# 1       Pd 4nm                        300.000000
# 2       Pd 4nm                        310.526316
# 3       Pd 4nm                        321.052632
# 4       Pd 4nm                        331.578947
# 5       Pd 4nm                        342.105263
# 6       Pd 4nm                        352.631579
# 7       Pd 4nm                        363.157895
# 8       Pd 4nm                        373.684211
# 9       Pd 4nm                        384.210526
# 10      Pd 4nm                        300.000000
# 11      Pd 4nm                        310.526316
# 12      Pd 4nm                        321.052632
# 13      Pd 4nm                        331.578947
# 14      Pd 4nm                        342.105263
# 15      Pd 4nm                        352.631579
# 16      Pd 4nm                        363.157895
# 17      Pd 4nm                        373.684211
# 18      Pd 4nm                        384.210526
# 19      Pt 4nm                        300.000000
# 20      Pt 4nm                        310.526316
# 21      Pt 4nm                        321.052632
# 22      Pt 4nm                        331.578947
# 23      Pt 4nm                        342.105263
# 24      Pt 4nm                        352.631579
# 25      Pt 4nm                        363.157895
# 26      Pt 4nm                        373.684211
# 27      Pt 4nm                        384.210526
# 28      Pt 4nm                        300.000000
# 29      Pt 4nm                        310.526316
# 30      Pt 4nm                        321.052632
# 31      Pt 4nm                        331.578947
# 32      Pt 4nm                        342.105263
# 33      Pt 4nm                        352.631579
# 34      Pt 4nm                        363.157895
# 35      Pt 4nm                        373.684211
# 36      Pt 4nm                        384.210526
# 37      Cu 4nm                        300.000000
# 38      Cu 4nm                        310.526316
# 39      Cu 4nm                        321.052632
# 40      Cu 4nm                        331.578947
# 41      Cu 4nm                        342.105263
# 42      Cu 4nm                        352.631579
# 43      Cu 4nm                        363.157895
# 44      Cu 4nm                        373.684211
# 45      Cu 4nm                        384.210526
# 46      Cu 4nm                        300.000000
# 47      Cu 4nm                        310.526316
# 48      Cu 4nm                        321.052632
# 49      Cu 4nm                        331.578947
# 50      Cu 4nm                        342.105263
# 51      Cu 4nm                        352.631579
# 52      Cu 4nm                        363.157895
# 53      Cu 4nm                        373.684211
# 54      Cu 4nm                        384.210526
#
#        dehydr. reaction pressure (bar) pathway process location function  \
# run #
# 1                                  1.0     all     all      all      all
# 2                                  1.0     all     all      all      all
# 3                                  1.0     all     all      all      all
# 4                                  1.0     all     all      all      all
# 5                                  1.0     all     all      all      all
# 6                                  1.0     all     all      all      all
# 7                                  1.0     all     all      all      all
# 8                                  1.0     all     all      all      all
# 9                                  1.0     all     all      all      all
# 10                               100.0     all     all      all      all
# 11                               100.0     all     all      all      all
# 12                               100.0     all     all      all      all
# 13                               100.0     all     all      all      all
# 14                               100.0     all     all      all      all
# 15                               100.0     all     all      all      all
# 16                               100.0     all     all      all      all
# 17                               100.0     all     all      all      all
# 18                               100.0     all     all      all      all
# 19                                 1.0     all     all      all      all
# 20                                 1.0     all     all      all      all
# 21                                 1.0     all     all      all      all
# 22                                 1.0     all     all      all      all
# 23                                 1.0     all     all      all      all
# 24                                 1.0     all     all      all      all
# 25                                 1.0     all     all      all      all
# 26                                 1.0     all     all      all      all
# 27                                 1.0     all     all      all      all
# 28                               100.0     all     all      all      all
# 29                               100.0     all     all      all      all
# 30                               100.0     all     all      all      all
# 31                               100.0     all     all      all      all
# 32                               100.0     all     all      all      all
# 33                               100.0     all     all      all      all
# 34                               100.0     all     all      all      all
# 35                               100.0     all     all      all      all
# 36                               100.0     all     all      all      all
# 37                                 1.0     all     all      all      all
# 38                                 1.0     all     all      all      all
# 39                                 1.0     all     all      all      all
# 40                                 1.0     all     all      all      all
# 41                                 1.0     all     all      all      all
# 42                                 1.0     all     all      all      all
# 43                                 1.0     all     all      all      all
# 44                                 1.0     all     all      all      all
# 45                                 1.0     all     all      all      all
# 46                               100.0     all     all      all      all
# 47                               100.0     all     all      all      all
# 48                               100.0     all     all      all      all
# 49                               100.0     all     all      all      all
# 50                               100.0     all     all      all      all
# 51                               100.0     all     all      all      all
# 52                               100.0     all     all      all      all
# 53                               100.0     all     all      all      all
# 54                               100.0     all     all      all      all
#
#       equipment   variable group            variable name unit        value
# run #
# 1           all  input parameter  dehydr. catalyst amount   kg     9.646712
# 2           all  input parameter  dehydr. catalyst amount   kg     4.048170
# 3           all  input parameter  dehydr. catalyst amount   kg     1.799780
# 4           all  input parameter  dehydr. catalyst amount   kg     0.841840
# 5           all  input parameter  dehydr. catalyst amount   kg     0.413009
# 6           all  input parameter  dehydr. catalyst amount   kg     0.211129
# 7           all  input parameter  dehydr. catalyst amount   kg     0.112166
# 8           all  input parameter  dehydr. catalyst amount   kg     0.062021
# 9           all  input parameter  dehydr. catalyst amount   kg     0.035629
# 10          all  input parameter  dehydr. catalyst amount   kg    10.030866
# 11          all  input parameter  dehydr. catalyst amount   kg     4.109109
# 12          all  input parameter  dehydr. catalyst amount   kg     1.781009
# 13          all  input parameter  dehydr. catalyst amount   kg     0.814131
# 14          all  input parameter  dehydr. catalyst amount   kg     0.390578
# 15          all  input parameter  dehydr. catalyst amount   kg     0.196615
# 16          all  input parameter  dehydr. catalyst amount   kg     0.102929
# 17          all  input parameter  dehydr. catalyst amount   kg     0.055423
# 18          all  input parameter  dehydr. catalyst amount   kg     0.030877
# 19          all  input parameter  dehydr. catalyst amount   kg  2500.462118
# 20          all  input parameter  dehydr. catalyst amount   kg   757.050839
# 21          all  input parameter  dehydr. catalyst amount   kg   290.257680
# 22          all  input parameter  dehydr. catalyst amount   kg   131.935309
# 23          all  input parameter  dehydr. catalyst amount   kg    59.370889
# 24          all  input parameter  dehydr. catalyst amount   kg    27.706415
# 25          all  input parameter  dehydr. catalyst amount   kg    13.193531
# 26          all  input parameter  dehydr. catalyst amount   kg     6.860636
# 27          all  input parameter  dehydr. catalyst amount   kg     3.958059
# 28          all  input parameter  dehydr. catalyst amount   kg  2500.462118
# 29          all  input parameter  dehydr. catalyst amount   kg   757.050839
# 30          all  input parameter  dehydr. catalyst amount   kg   290.257680
# 31          all  input parameter  dehydr. catalyst amount   kg   109.506307
# 32          all  input parameter  dehydr. catalyst amount   kg    46.177358
# 33          all  input parameter  dehydr. catalyst amount   kg    19.790296
# 34          all  input parameter  dehydr. catalyst amount   kg     9.103536
# 35          all  input parameter  dehydr. catalyst amount   kg     4.353865
# 36          all  input parameter  dehydr. catalyst amount   kg     2.242900
# 37          all  input parameter  dehydr. catalyst amount   kg   203.635280
# 38          all  input parameter  dehydr. catalyst amount   kg   135.761207
# 39          all  input parameter  dehydr. catalyst amount   kg   102.898767
# 40          all  input parameter  dehydr. catalyst amount   kg    76.514468
# 41          all  input parameter  dehydr. catalyst amount   kg    54.087813
# 42          all  input parameter  dehydr. catalyst amount   kg    38.257234
# 43          all  input parameter  dehydr. catalyst amount   kg    29.022729
# 44          all  input parameter  dehydr. catalyst amount   kg    22.426654
# 45          all  input parameter  dehydr. catalyst amount   kg    15.830580
# 46          all  input parameter  dehydr. catalyst amount   kg    14.299183
# 47          all  input parameter  dehydr. catalyst amount   kg     7.413385
# 48          all  input parameter  dehydr. catalyst amount   kg     4.617252
# 49          all  input parameter  dehydr. catalyst amount   kg     2.638430
# 50          all  input parameter  dehydr. catalyst amount   kg     1.583058
# 51          all  input parameter  dehydr. catalyst amount   kg     0.923450
# 52          all  input parameter  dehydr. catalyst amount   kg     0.659607
# 53          all  input parameter  dehydr. catalyst amount   kg     0.395764
# 54          all  input parameter  dehydr. catalyst amount   kg     0.237459

# %%
# filter catalyst amout by pressure
df_catal_amt_kg_pres = df_catal_amt_kg.loc[
    df_catal_amt_kg['dehydr. reaction pressure (bar)'].isin(
        dehydr_pres_bar_to_plot
        )
    ].copy()

# add column for temperature in deg.C
df_catal_amt_kg_pres['dehydr. reaction temperature (C)'] = \
    df_catal_amt_kg_pres['dehydr. reaction temperature (K)'] - 273.15

# drop column for temperature in K
df_catal_amt_kg_pres.drop(
    columns = 'dehydr. reaction temperature (K)', 
    inplace = True
    )

# combine catalyst type and pressure columns
df_catal_amt_kg_pres['catalyst, pressure'] = \
    df_catal_amt_kg_pres['scenario'] + ', ' + \
    df_catal_amt_kg_pres['dehydr. reaction pressure (bar)'].astype(int).astype(str) + \
    ' bar'

df_catal_amt_kg_pres
# Out:
#       scenario  dehydr. reaction pressure (bar) pathway process location  \
# run #
# 1       Pd 4nm                              1.0     all     all      all
# 2       Pd 4nm                              1.0     all     all      all
# 3       Pd 4nm                              1.0     all     all      all
# 4       Pd 4nm                              1.0     all     all      all
# 5       Pd 4nm                              1.0     all     all      all
# 6       Pd 4nm                              1.0     all     all      all
# 7       Pd 4nm                              1.0     all     all      all
# 8       Pd 4nm                              1.0     all     all      all
# 9       Pd 4nm                              1.0     all     all      all
# 10      Pd 4nm                            100.0     all     all      all
# 11      Pd 4nm                            100.0     all     all      all
# 12      Pd 4nm                            100.0     all     all      all
# 13      Pd 4nm                            100.0     all     all      all
# 14      Pd 4nm                            100.0     all     all      all
# 15      Pd 4nm                            100.0     all     all      all
# 16      Pd 4nm                            100.0     all     all      all
# 17      Pd 4nm                            100.0     all     all      all
# 18      Pd 4nm                            100.0     all     all      all
# 19      Pt 4nm                              1.0     all     all      all
# 20      Pt 4nm                              1.0     all     all      all
# 21      Pt 4nm                              1.0     all     all      all
# 22      Pt 4nm                              1.0     all     all      all
# 23      Pt 4nm                              1.0     all     all      all
# 24      Pt 4nm                              1.0     all     all      all
# 25      Pt 4nm                              1.0     all     all      all
# 26      Pt 4nm                              1.0     all     all      all
# 27      Pt 4nm                              1.0     all     all      all
# 28      Pt 4nm                            100.0     all     all      all
# 29      Pt 4nm                            100.0     all     all      all
# 30      Pt 4nm                            100.0     all     all      all
# 31      Pt 4nm                            100.0     all     all      all
# 32      Pt 4nm                            100.0     all     all      all
# 33      Pt 4nm                            100.0     all     all      all
# 34      Pt 4nm                            100.0     all     all      all
# 35      Pt 4nm                            100.0     all     all      all
# 36      Pt 4nm                            100.0     all     all      all
# 37      Cu 4nm                              1.0     all     all      all
# 38      Cu 4nm                              1.0     all     all      all
# 39      Cu 4nm                              1.0     all     all      all
# 40      Cu 4nm                              1.0     all     all      all
# 41      Cu 4nm                              1.0     all     all      all
# 42      Cu 4nm                              1.0     all     all      all
# 43      Cu 4nm                              1.0     all     all      all
# 44      Cu 4nm                              1.0     all     all      all
# 45      Cu 4nm                              1.0     all     all      all
# 46      Cu 4nm                            100.0     all     all      all
# 47      Cu 4nm                            100.0     all     all      all
# 48      Cu 4nm                            100.0     all     all      all
# 49      Cu 4nm                            100.0     all     all      all
# 50      Cu 4nm                            100.0     all     all      all
# 51      Cu 4nm                            100.0     all     all      all
# 52      Cu 4nm                            100.0     all     all      all
# 53      Cu 4nm                            100.0     all     all      all
# 54      Cu 4nm                            100.0     all     all      all
#
#       function equipment   variable group            variable name unit  \
# run #
# 1          all       all  input parameter  dehydr. catalyst amount   kg
# 2          all       all  input parameter  dehydr. catalyst amount   kg
# 3          all       all  input parameter  dehydr. catalyst amount   kg
# 4          all       all  input parameter  dehydr. catalyst amount   kg
# 5          all       all  input parameter  dehydr. catalyst amount   kg
# 6          all       all  input parameter  dehydr. catalyst amount   kg
# 7          all       all  input parameter  dehydr. catalyst amount   kg
# 8          all       all  input parameter  dehydr. catalyst amount   kg
# 9          all       all  input parameter  dehydr. catalyst amount   kg
# 10         all       all  input parameter  dehydr. catalyst amount   kg
# 11         all       all  input parameter  dehydr. catalyst amount   kg
# 12         all       all  input parameter  dehydr. catalyst amount   kg
# 13         all       all  input parameter  dehydr. catalyst amount   kg
# 14         all       all  input parameter  dehydr. catalyst amount   kg
# 15         all       all  input parameter  dehydr. catalyst amount   kg
# 16         all       all  input parameter  dehydr. catalyst amount   kg
# 17         all       all  input parameter  dehydr. catalyst amount   kg
# 18         all       all  input parameter  dehydr. catalyst amount   kg
# 19         all       all  input parameter  dehydr. catalyst amount   kg
# 20         all       all  input parameter  dehydr. catalyst amount   kg
# 21         all       all  input parameter  dehydr. catalyst amount   kg
# 22         all       all  input parameter  dehydr. catalyst amount   kg
# 23         all       all  input parameter  dehydr. catalyst amount   kg
# 24         all       all  input parameter  dehydr. catalyst amount   kg
# 25         all       all  input parameter  dehydr. catalyst amount   kg
# 26         all       all  input parameter  dehydr. catalyst amount   kg
# 27         all       all  input parameter  dehydr. catalyst amount   kg
# 28         all       all  input parameter  dehydr. catalyst amount   kg
# 29         all       all  input parameter  dehydr. catalyst amount   kg
# 30         all       all  input parameter  dehydr. catalyst amount   kg
# 31         all       all  input parameter  dehydr. catalyst amount   kg
# 32         all       all  input parameter  dehydr. catalyst amount   kg
# 33         all       all  input parameter  dehydr. catalyst amount   kg
# 34         all       all  input parameter  dehydr. catalyst amount   kg
# 35         all       all  input parameter  dehydr. catalyst amount   kg
# 36         all       all  input parameter  dehydr. catalyst amount   kg
# 37         all       all  input parameter  dehydr. catalyst amount   kg
# 38         all       all  input parameter  dehydr. catalyst amount   kg
# 39         all       all  input parameter  dehydr. catalyst amount   kg
# 40         all       all  input parameter  dehydr. catalyst amount   kg
# 41         all       all  input parameter  dehydr. catalyst amount   kg
# 42         all       all  input parameter  dehydr. catalyst amount   kg
# 43         all       all  input parameter  dehydr. catalyst amount   kg
# 44         all       all  input parameter  dehydr. catalyst amount   kg
# 45         all       all  input parameter  dehydr. catalyst amount   kg
# 46         all       all  input parameter  dehydr. catalyst amount   kg
# 47         all       all  input parameter  dehydr. catalyst amount   kg
# 48         all       all  input parameter  dehydr. catalyst amount   kg
# 49         all       all  input parameter  dehydr. catalyst amount   kg
# 50         all       all  input parameter  dehydr. catalyst amount   kg
# 51         all       all  input parameter  dehydr. catalyst amount   kg
# 52         all       all  input parameter  dehydr. catalyst amount   kg
# 53         all       all  input parameter  dehydr. catalyst amount   kg
# 54         all       all  input parameter  dehydr. catalyst amount   kg
#
#              value  dehydr. reaction temperature (C) catalyst, pressure
# run #
# 1         9.646712                         26.850000      Pd 4nm, 1 bar
# 2         4.048170                         37.376316      Pd 4nm, 1 bar
# 3         1.799780                         47.902632      Pd 4nm, 1 bar
# 4         0.841840                         58.428947      Pd 4nm, 1 bar
# 5         0.413009                         68.955263      Pd 4nm, 1 bar
# 6         0.211129                         79.481579      Pd 4nm, 1 bar
# 7         0.112166                         90.007895      Pd 4nm, 1 bar
# 8         0.062021                        100.534211      Pd 4nm, 1 bar
# 9         0.035629                        111.060526      Pd 4nm, 1 bar
# 10       10.030866                         26.850000    Pd 4nm, 100 bar
# 11        4.109109                         37.376316    Pd 4nm, 100 bar
# 12        1.781009                         47.902632    Pd 4nm, 100 bar
# 13        0.814131                         58.428947    Pd 4nm, 100 bar
# 14        0.390578                         68.955263    Pd 4nm, 100 bar
# 15        0.196615                         79.481579    Pd 4nm, 100 bar
# 16        0.102929                         90.007895    Pd 4nm, 100 bar
# 17        0.055423                        100.534211    Pd 4nm, 100 bar
# 18        0.030877                        111.060526    Pd 4nm, 100 bar
# 19     2500.462118                         26.850000      Pt 4nm, 1 bar
# 20      757.050839                         37.376316      Pt 4nm, 1 bar
# 21      290.257680                         47.902632      Pt 4nm, 1 bar
# 22      131.935309                         58.428947      Pt 4nm, 1 bar
# 23       59.370889                         68.955263      Pt 4nm, 1 bar
# 24       27.706415                         79.481579      Pt 4nm, 1 bar
# 25       13.193531                         90.007895      Pt 4nm, 1 bar
# 26        6.860636                        100.534211      Pt 4nm, 1 bar
# 27        3.958059                        111.060526      Pt 4nm, 1 bar
# 28     2500.462118                         26.850000    Pt 4nm, 100 bar
# 29      757.050839                         37.376316    Pt 4nm, 100 bar
# 30      290.257680                         47.902632    Pt 4nm, 100 bar
# 31      109.506307                         58.428947    Pt 4nm, 100 bar
# 32       46.177358                         68.955263    Pt 4nm, 100 bar
# 33       19.790296                         79.481579    Pt 4nm, 100 bar
# 34        9.103536                         90.007895    Pt 4nm, 100 bar
# 35        4.353865                        100.534211    Pt 4nm, 100 bar
# 36        2.242900                        111.060526    Pt 4nm, 100 bar
# 37      203.635280                         26.850000      Cu 4nm, 1 bar
# 38      135.761207                         37.376316      Cu 4nm, 1 bar
# 39      102.898767                         47.902632      Cu 4nm, 1 bar
# 40       76.514468                         58.428947      Cu 4nm, 1 bar
# 41       54.087813                         68.955263      Cu 4nm, 1 bar
# 42       38.257234                         79.481579      Cu 4nm, 1 bar
# 43       29.022729                         90.007895      Cu 4nm, 1 bar
# 44       22.426654                        100.534211      Cu 4nm, 1 bar
# 45       15.830580                        111.060526      Cu 4nm, 1 bar
# 46       14.299183                         26.850000    Cu 4nm, 100 bar
# 47        7.413385                         37.376316    Cu 4nm, 100 bar
# 48        4.617252                         47.902632    Cu 4nm, 100 bar
# 49        2.638430                         58.428947    Cu 4nm, 100 bar
# 50        1.583058                         68.955263    Cu 4nm, 100 bar
# 51        0.923450                         79.481579    Cu 4nm, 100 bar
# 52        0.659607                         90.007895    Cu 4nm, 100 bar
# 53        0.395764                        100.534211    Cu 4nm, 100 bar
# 54        0.237459                        111.060526    Cu 4nm, 100 bar

# %%
# pivot catalyst amount dataframe
df_catal_amt_kg_pivot = df_catal_amt_kg_pres.pivot(
    columns = ['catalyst, pressure'],
    index = 'dehydr. reaction temperature (C)',
    values = 'value'
    )

df_catal_amt_kg_pivot
# Out:
# catalyst, pressure                Cu 4nm, 1 bar  Cu 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                            203.635280        14.299183
# 37.376316                            135.761207         7.413385
# 47.902632                            102.898767         4.617252
# 58.428947                             76.514468         2.638430
# 68.955263                             54.087813         1.583058
# 79.481579                             38.257234         0.923450
# 90.007895                             29.022729         0.659607
# 100.534211                            22.426654         0.395764
# 111.060526                            15.830580         0.237459
#
# catalyst, pressure                Pd 4nm, 1 bar  Pd 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                              9.646712        10.030866
# 37.376316                              4.048170         4.109109
# 47.902632                              1.799780         1.781009
# 58.428947                              0.841840         0.814131
# 68.955263                              0.413009         0.390578
# 79.481579                              0.211129         0.196615
# 90.007895                              0.112166         0.102929
# 100.534211                             0.062021         0.055423
# 111.060526                             0.035629         0.030877
#
# catalyst, pressure                Pt 4nm, 1 bar  Pt 4nm, 100 bar
# dehydr. reaction temperature (C)
# 26.850000                           2500.462118      2500.462118
# 37.376316                            757.050839       757.050839
# 47.902632                            290.257680       290.257680
# 58.428947                            131.935309       109.506307
# 68.955263                             59.370889        46.177358
# 79.481579                             27.706415        19.790296
# 90.007895                             13.193531         9.103536
# 100.534211                             6.860636         4.353865
# 111.060526                             3.958059         2.242900

# %% [markdown]
# ### DATA PROCESSING: catalyst purchase cost

# %%
# filter for catalyst cost results
df_catal_cost = df_stn.loc[
    (df_stn['equipment'] == 'catalyst') & \
    (df_stn['unit'] == '$/station')
    ].copy()

# rename columns
df_catal_cost.rename(
    columns = {
        'value' : '$/station'
        }, 
    inplace = True
    )

df_catal_cost
# Out:
#       scenario  dehydr. reaction temperature (K)  \
# run #
# 1       Pd 4nm                        300.000000
# 2       Pd 4nm                        310.526316
# 3       Pd 4nm                        321.052632
# 4       Pd 4nm                        331.578947
# 5       Pd 4nm                        342.105263
# 6       Pd 4nm                        352.631579
# 7       Pd 4nm                        363.157895
# 8       Pd 4nm                        373.684211
# 9       Pd 4nm                        384.210526
# 10      Pd 4nm                        300.000000
# 11      Pd 4nm                        310.526316
# 12      Pd 4nm                        321.052632
# 13      Pd 4nm                        331.578947
# 14      Pd 4nm                        342.105263
# 15      Pd 4nm                        352.631579
# 16      Pd 4nm                        363.157895
# 17      Pd 4nm                        373.684211
# 18      Pd 4nm                        384.210526
# 19      Pt 4nm                        300.000000
# 20      Pt 4nm                        310.526316
# 21      Pt 4nm                        321.052632
# 22      Pt 4nm                        331.578947
# 23      Pt 4nm                        342.105263
# 24      Pt 4nm                        352.631579
# 25      Pt 4nm                        363.157895
# 26      Pt 4nm                        373.684211
# 27      Pt 4nm                        384.210526
# 28      Pt 4nm                        300.000000
# 29      Pt 4nm                        310.526316
# 30      Pt 4nm                        321.052632
# 31      Pt 4nm                        331.578947
# 32      Pt 4nm                        342.105263
# 33      Pt 4nm                        352.631579
# 34      Pt 4nm                        363.157895
# 35      Pt 4nm                        373.684211
# 36      Pt 4nm                        384.210526
# 37      Cu 4nm                        300.000000
# 38      Cu 4nm                        310.526316
# 39      Cu 4nm                        321.052632
# 40      Cu 4nm                        331.578947
# 41      Cu 4nm                        342.105263
# 42      Cu 4nm                        352.631579
# 43      Cu 4nm                        363.157895
# 44      Cu 4nm                        373.684211
# 45      Cu 4nm                        384.210526
# 46      Cu 4nm                        300.000000
# 47      Cu 4nm                        310.526316
# 48      Cu 4nm                        321.052632
# 49      Cu 4nm                        331.578947
# 50      Cu 4nm                        342.105263
# 51      Cu 4nm                        352.631579
# 52      Cu 4nm                        363.157895
# 53      Cu 4nm                        373.684211
# 54      Cu 4nm                        384.210526
#
#        dehydr. reaction pressure (bar)             pathway         process  \
# run #
# 1                                  1.0  LOHC - formic acid  reconditioning
# 2                                  1.0  LOHC - formic acid  reconditioning
# 3                                  1.0  LOHC - formic acid  reconditioning
# 4                                  1.0  LOHC - formic acid  reconditioning
# 5                                  1.0  LOHC - formic acid  reconditioning
# 6                                  1.0  LOHC - formic acid  reconditioning
# 7                                  1.0  LOHC - formic acid  reconditioning
# 8                                  1.0  LOHC - formic acid  reconditioning
# 9                                  1.0  LOHC - formic acid  reconditioning
# 10                               100.0  LOHC - formic acid  reconditioning
# 11                               100.0  LOHC - formic acid  reconditioning
# 12                               100.0  LOHC - formic acid  reconditioning
# 13                               100.0  LOHC - formic acid  reconditioning
# 14                               100.0  LOHC - formic acid  reconditioning
# 15                               100.0  LOHC - formic acid  reconditioning
# 16                               100.0  LOHC - formic acid  reconditioning
# 17                               100.0  LOHC - formic acid  reconditioning
# 18                               100.0  LOHC - formic acid  reconditioning
# 19                                 1.0  LOHC - formic acid  reconditioning
# 20                                 1.0  LOHC - formic acid  reconditioning
# 21                                 1.0  LOHC - formic acid  reconditioning
# 22                                 1.0  LOHC - formic acid  reconditioning
# 23                                 1.0  LOHC - formic acid  reconditioning
# 24                                 1.0  LOHC - formic acid  reconditioning
# 25                                 1.0  LOHC - formic acid  reconditioning
# 26                                 1.0  LOHC - formic acid  reconditioning
# 27                                 1.0  LOHC - formic acid  reconditioning
# 28                               100.0  LOHC - formic acid  reconditioning
# 29                               100.0  LOHC - formic acid  reconditioning
# 30                               100.0  LOHC - formic acid  reconditioning
# 31                               100.0  LOHC - formic acid  reconditioning
# 32                               100.0  LOHC - formic acid  reconditioning
# 33                               100.0  LOHC - formic acid  reconditioning
# 34                               100.0  LOHC - formic acid  reconditioning
# 35                               100.0  LOHC - formic acid  reconditioning
# 36                               100.0  LOHC - formic acid  reconditioning
# 37                                 1.0  LOHC - formic acid  reconditioning
# 38                                 1.0  LOHC - formic acid  reconditioning
# 39                                 1.0  LOHC - formic acid  reconditioning
# 40                                 1.0  LOHC - formic acid  reconditioning
# 41                                 1.0  LOHC - formic acid  reconditioning
# 42                                 1.0  LOHC - formic acid  reconditioning
# 43                                 1.0  LOHC - formic acid  reconditioning
# 44                                 1.0  LOHC - formic acid  reconditioning
# 45                                 1.0  LOHC - formic acid  reconditioning
# 46                               100.0  LOHC - formic acid  reconditioning
# 47                               100.0  LOHC - formic acid  reconditioning
# 48                               100.0  LOHC - formic acid  reconditioning
# 49                               100.0  LOHC - formic acid  reconditioning
# 50                               100.0  LOHC - formic acid  reconditioning
# 51                               100.0  LOHC - formic acid  reconditioning
# 52                               100.0  LOHC - formic acid  reconditioning
# 53                               100.0  LOHC - formic acid  reconditioning
# 54                               100.0  LOHC - formic acid  reconditioning
#
#                 location  function equipment variable group  variable name  \
# run #
# 1      refueling station  reaction  catalyst   capital cost  purchase cost
# 2      refueling station  reaction  catalyst   capital cost  purchase cost
# 3      refueling station  reaction  catalyst   capital cost  purchase cost
# 4      refueling station  reaction  catalyst   capital cost  purchase cost
# 5      refueling station  reaction  catalyst   capital cost  purchase cost
# 6      refueling station  reaction  catalyst   capital cost  purchase cost
# 7      refueling station  reaction  catalyst   capital cost  purchase cost
# 8      refueling station  reaction  catalyst   capital cost  purchase cost
# 9      refueling station  reaction  catalyst   capital cost  purchase cost
# 10     refueling station  reaction  catalyst   capital cost  purchase cost
# 11     refueling station  reaction  catalyst   capital cost  purchase cost
# 12     refueling station  reaction  catalyst   capital cost  purchase cost
# 13     refueling station  reaction  catalyst   capital cost  purchase cost
# 14     refueling station  reaction  catalyst   capital cost  purchase cost
# 15     refueling station  reaction  catalyst   capital cost  purchase cost
# 16     refueling station  reaction  catalyst   capital cost  purchase cost
# 17     refueling station  reaction  catalyst   capital cost  purchase cost
# 18     refueling station  reaction  catalyst   capital cost  purchase cost
# 19     refueling station  reaction  catalyst   capital cost  purchase cost
# 20     refueling station  reaction  catalyst   capital cost  purchase cost
# 21     refueling station  reaction  catalyst   capital cost  purchase cost
# 22     refueling station  reaction  catalyst   capital cost  purchase cost
# 23     refueling station  reaction  catalyst   capital cost  purchase cost
# 24     refueling station  reaction  catalyst   capital cost  purchase cost
# 25     refueling station  reaction  catalyst   capital cost  purchase cost
# 26     refueling station  reaction  catalyst   capital cost  purchase cost
# 27     refueling station  reaction  catalyst   capital cost  purchase cost
# 28     refueling station  reaction  catalyst   capital cost  purchase cost
# 29     refueling station  reaction  catalyst   capital cost  purchase cost
# 30     refueling station  reaction  catalyst   capital cost  purchase cost
# 31     refueling station  reaction  catalyst   capital cost  purchase cost
# 32     refueling station  reaction  catalyst   capital cost  purchase cost
# 33     refueling station  reaction  catalyst   capital cost  purchase cost
# 34     refueling station  reaction  catalyst   capital cost  purchase cost
# 35     refueling station  reaction  catalyst   capital cost  purchase cost
# 36     refueling station  reaction  catalyst   capital cost  purchase cost
# 37     refueling station  reaction  catalyst   capital cost  purchase cost
# 38     refueling station  reaction  catalyst   capital cost  purchase cost
# 39     refueling station  reaction  catalyst   capital cost  purchase cost
# 40     refueling station  reaction  catalyst   capital cost  purchase cost
# 41     refueling station  reaction  catalyst   capital cost  purchase cost
# 42     refueling station  reaction  catalyst   capital cost  purchase cost
# 43     refueling station  reaction  catalyst   capital cost  purchase cost
# 44     refueling station  reaction  catalyst   capital cost  purchase cost
# 45     refueling station  reaction  catalyst   capital cost  purchase cost
# 46     refueling station  reaction  catalyst   capital cost  purchase cost
# 47     refueling station  reaction  catalyst   capital cost  purchase cost
# 48     refueling station  reaction  catalyst   capital cost  purchase cost
# 49     refueling station  reaction  catalyst   capital cost  purchase cost
# 50     refueling station  reaction  catalyst   capital cost  purchase cost
# 51     refueling station  reaction  catalyst   capital cost  purchase cost
# 52     refueling station  reaction  catalyst   capital cost  purchase cost
# 53     refueling station  reaction  catalyst   capital cost  purchase cost
# 54     refueling station  reaction  catalyst   capital cost  purchase cost
#
#             unit     $/station
# run #
# 1      $/station  3.376349e+04
# 2      $/station  1.416859e+04
# 3      $/station  6.299231e+03
# 4      $/station  2.946439e+03
# 5      $/station  1.445533e+03
# 6      $/station  7.389530e+02
# 7      $/station  3.925803e+02
# 8      $/station  2.170740e+02
# 9      $/station  1.247022e+02
# 10     $/station  3.510803e+04
# 11     $/station  1.438188e+04
# 12     $/station  6.233533e+03
# 13     $/station  2.849457e+03
# 14     $/station  1.367024e+03
# 15     $/station  6.881532e+02
# 16     $/station  3.602502e+02
# 17     $/station  1.939810e+02
# 18     $/station  1.080698e+02
# 19     $/station  7.501386e+06
# 20     $/station  2.271153e+06
# 21     $/station  8.707730e+05
# 22     $/station  3.958059e+05
# 23     $/station  1.781127e+05
# 24     $/station  8.311924e+04
# 25     $/station  3.958059e+04
# 26     $/station  2.058191e+04
# 27     $/station  1.187418e+04
# 28     $/station  7.501386e+06
# 29     $/station  2.271153e+06
# 30     $/station  8.707730e+05
# 31     $/station  3.285189e+05
# 32     $/station  1.385321e+05
# 33     $/station  5.937089e+04
# 34     $/station  2.731061e+04
# 35     $/station  1.306160e+04
# 36     $/station  6.728701e+03
# 37     $/station  2.850894e+05
# 38     $/station  1.900657e+05
# 39     $/station  1.440583e+05
# 40     $/station  1.071203e+05
# 41     $/station  7.572294e+04
# 42     $/station  5.356013e+04
# 43     $/station  4.063182e+04
# 44     $/station  3.139732e+04
# 45     $/station  2.216281e+04
# 46     $/station  2.001886e+04
# 47     $/station  1.037874e+04
# 48     $/station  6.464153e+03
# 49     $/station  3.693802e+03
# 50     $/station  2.216281e+03
# 51     $/station  1.292831e+03
# 52     $/station  9.234505e+02
# 53     $/station  5.540703e+02
# 54     $/station  3.324422e+02

# %%
# filter catalyst cost results by pressure
df_catal_cost_pres = df_catal_cost.loc[
    df_catal_cost['dehydr. reaction pressure (bar)'].isin(
        dehydr_pres_bar_to_plot
        )
    ].copy()

# add column for temperature in deg.C
df_catal_cost_pres['dehydr. reaction temperature (C)'] = \
    df_catal_cost_pres['dehydr. reaction temperature (K)'] - 273.15

# drop column for temperature in K
df_catal_cost_pres.drop(
    columns = 'dehydr. reaction temperature (K)', 
    inplace = True
    )

# combine catalyst type and pressure columns
df_catal_cost_pres['catalyst, pressure'] = \
    df_catal_cost_pres['scenario'] + ', ' + \
    df_catal_cost_pres['dehydr. reaction pressure (bar)'].astype(int).astype(str) + \
    ' bar'

df_catal_cost_pres
# Out:
#       scenario  dehydr. reaction pressure (bar)             pathway  \
# run #
# 1       Pd 4nm                              1.0  LOHC - formic acid
# 2       Pd 4nm                              1.0  LOHC - formic acid
# 3       Pd 4nm                              1.0  LOHC - formic acid
# 4       Pd 4nm                              1.0  LOHC - formic acid
# 5       Pd 4nm                              1.0  LOHC - formic acid
# 6       Pd 4nm                              1.0  LOHC - formic acid
# 7       Pd 4nm                              1.0  LOHC - formic acid
# 8       Pd 4nm                              1.0  LOHC - formic acid
# 9       Pd 4nm                              1.0  LOHC - formic acid
# 10      Pd 4nm                            100.0  LOHC - formic acid
# 11      Pd 4nm                            100.0  LOHC - formic acid
# 12      Pd 4nm                            100.0  LOHC - formic acid
# 13      Pd 4nm                            100.0  LOHC - formic acid
# 14      Pd 4nm                            100.0  LOHC - formic acid
# 15      Pd 4nm                            100.0  LOHC - formic acid
# 16      Pd 4nm                            100.0  LOHC - formic acid
# 17      Pd 4nm                            100.0  LOHC - formic acid
# 18      Pd 4nm                            100.0  LOHC - formic acid
# 19      Pt 4nm                              1.0  LOHC - formic acid
# 20      Pt 4nm                              1.0  LOHC - formic acid
# 21      Pt 4nm                              1.0  LOHC - formic acid
# 22      Pt 4nm                              1.0  LOHC - formic acid
# 23      Pt 4nm                              1.0  LOHC - formic acid
# 24      Pt 4nm                              1.0  LOHC - formic acid
# 25      Pt 4nm                              1.0  LOHC - formic acid
# 26      Pt 4nm                              1.0  LOHC - formic acid
# 27      Pt 4nm                              1.0  LOHC - formic acid
# 28      Pt 4nm                            100.0  LOHC - formic acid
# 29      Pt 4nm                            100.0  LOHC - formic acid
# 30      Pt 4nm                            100.0  LOHC - formic acid
# 31      Pt 4nm                            100.0  LOHC - formic acid
# 32      Pt 4nm                            100.0  LOHC - formic acid
# 33      Pt 4nm                            100.0  LOHC - formic acid
# 34      Pt 4nm                            100.0  LOHC - formic acid
# 35      Pt 4nm                            100.0  LOHC - formic acid
# 36      Pt 4nm                            100.0  LOHC - formic acid
# 37      Cu 4nm                              1.0  LOHC - formic acid
# 38      Cu 4nm                              1.0  LOHC - formic acid
# 39      Cu 4nm                              1.0  LOHC - formic acid
# 40      Cu 4nm                              1.0  LOHC - formic acid
# 41      Cu 4nm                              1.0  LOHC - formic acid
# 42      Cu 4nm                              1.0  LOHC - formic acid
# 43      Cu 4nm                              1.0  LOHC - formic acid
# 44      Cu 4nm                              1.0  LOHC - formic acid
# 45      Cu 4nm                              1.0  LOHC - formic acid
# 46      Cu 4nm                            100.0  LOHC - formic acid
# 47      Cu 4nm                            100.0  LOHC - formic acid
# 48      Cu 4nm                            100.0  LOHC - formic acid
# 49      Cu 4nm                            100.0  LOHC - formic acid
# 50      Cu 4nm                            100.0  LOHC - formic acid
# 51      Cu 4nm                            100.0  LOHC - formic acid
# 52      Cu 4nm                            100.0  LOHC - formic acid
# 53      Cu 4nm                            100.0  LOHC - formic acid
# 54      Cu 4nm                            100.0  LOHC - formic acid
#
#               process           location  function equipment variable group  \
# run #
# 1      reconditioning  refueling station  reaction  catalyst   capital cost
# 2      reconditioning  refueling station  reaction  catalyst   capital cost
# 3      reconditioning  refueling station  reaction  catalyst   capital cost
# 4      reconditioning  refueling station  reaction  catalyst   capital cost
# 5      reconditioning  refueling station  reaction  catalyst   capital cost
# 6      reconditioning  refueling station  reaction  catalyst   capital cost
# 7      reconditioning  refueling station  reaction  catalyst   capital cost
# 8      reconditioning  refueling station  reaction  catalyst   capital cost
# 9      reconditioning  refueling station  reaction  catalyst   capital cost
# 10     reconditioning  refueling station  reaction  catalyst   capital cost
# 11     reconditioning  refueling station  reaction  catalyst   capital cost
# 12     reconditioning  refueling station  reaction  catalyst   capital cost
# 13     reconditioning  refueling station  reaction  catalyst   capital cost
# 14     reconditioning  refueling station  reaction  catalyst   capital cost
# 15     reconditioning  refueling station  reaction  catalyst   capital cost
# 16     reconditioning  refueling station  reaction  catalyst   capital cost
# 17     reconditioning  refueling station  reaction  catalyst   capital cost
# 18     reconditioning  refueling station  reaction  catalyst   capital cost
# 19     reconditioning  refueling station  reaction  catalyst   capital cost
# 20     reconditioning  refueling station  reaction  catalyst   capital cost
# 21     reconditioning  refueling station  reaction  catalyst   capital cost
# 22     reconditioning  refueling station  reaction  catalyst   capital cost
# 23     reconditioning  refueling station  reaction  catalyst   capital cost
# 24     reconditioning  refueling station  reaction  catalyst   capital cost
# 25     reconditioning  refueling station  reaction  catalyst   capital cost
# 26     reconditioning  refueling station  reaction  catalyst   capital cost
# 27     reconditioning  refueling station  reaction  catalyst   capital cost
# 28     reconditioning  refueling station  reaction  catalyst   capital cost
# 29     reconditioning  refueling station  reaction  catalyst   capital cost
# 30     reconditioning  refueling station  reaction  catalyst   capital cost
# 31     reconditioning  refueling station  reaction  catalyst   capital cost
# 32     reconditioning  refueling station  reaction  catalyst   capital cost
# 33     reconditioning  refueling station  reaction  catalyst   capital cost
# 34     reconditioning  refueling station  reaction  catalyst   capital cost
# 35     reconditioning  refueling station  reaction  catalyst   capital cost
# 36     reconditioning  refueling station  reaction  catalyst   capital cost
# 37     reconditioning  refueling station  reaction  catalyst   capital cost
# 38     reconditioning  refueling station  reaction  catalyst   capital cost
# 39     reconditioning  refueling station  reaction  catalyst   capital cost
# 40     reconditioning  refueling station  reaction  catalyst   capital cost
# 41     reconditioning  refueling station  reaction  catalyst   capital cost
# 42     reconditioning  refueling station  reaction  catalyst   capital cost
# 43     reconditioning  refueling station  reaction  catalyst   capital cost
# 44     reconditioning  refueling station  reaction  catalyst   capital cost
# 45     reconditioning  refueling station  reaction  catalyst   capital cost
# 46     reconditioning  refueling station  reaction  catalyst   capital cost
# 47     reconditioning  refueling station  reaction  catalyst   capital cost
# 48     reconditioning  refueling station  reaction  catalyst   capital cost
# 49     reconditioning  refueling station  reaction  catalyst   capital cost
# 50     reconditioning  refueling station  reaction  catalyst   capital cost
# 51     reconditioning  refueling station  reaction  catalyst   capital cost
# 52     reconditioning  refueling station  reaction  catalyst   capital cost
# 53     reconditioning  refueling station  reaction  catalyst   capital cost
# 54     reconditioning  refueling station  reaction  catalyst   capital cost
#
#        variable name       unit     $/station  \
# run #
# 1      purchase cost  $/station  3.376349e+04
# 2      purchase cost  $/station  1.416859e+04
# 3      purchase cost  $/station  6.299231e+03
# 4      purchase cost  $/station  2.946439e+03
# 5      purchase cost  $/station  1.445533e+03
# 6      purchase cost  $/station  7.389530e+02
# 7      purchase cost  $/station  3.925803e+02
# 8      purchase cost  $/station  2.170740e+02
# 9      purchase cost  $/station  1.247022e+02
# 10     purchase cost  $/station  3.510803e+04
# 11     purchase cost  $/station  1.438188e+04
# 12     purchase cost  $/station  6.233533e+03
# 13     purchase cost  $/station  2.849457e+03
# 14     purchase cost  $/station  1.367024e+03
# 15     purchase cost  $/station  6.881532e+02
# 16     purchase cost  $/station  3.602502e+02
# 17     purchase cost  $/station  1.939810e+02
# 18     purchase cost  $/station  1.080698e+02
# 19     purchase cost  $/station  7.501386e+06
# 20     purchase cost  $/station  2.271153e+06
# 21     purchase cost  $/station  8.707730e+05
# 22     purchase cost  $/station  3.958059e+05
# 23     purchase cost  $/station  1.781127e+05
# 24     purchase cost  $/station  8.311924e+04
# 25     purchase cost  $/station  3.958059e+04
# 26     purchase cost  $/station  2.058191e+04
# 27     purchase cost  $/station  1.187418e+04
# 28     purchase cost  $/station  7.501386e+06
# 29     purchase cost  $/station  2.271153e+06
# 30     purchase cost  $/station  8.707730e+05
# 31     purchase cost  $/station  3.285189e+05
# 32     purchase cost  $/station  1.385321e+05
# 33     purchase cost  $/station  5.937089e+04
# 34     purchase cost  $/station  2.731061e+04
# 35     purchase cost  $/station  1.306160e+04
# 36     purchase cost  $/station  6.728701e+03
# 37     purchase cost  $/station  2.850894e+05
# 38     purchase cost  $/station  1.900657e+05
# 39     purchase cost  $/station  1.440583e+05
# 40     purchase cost  $/station  1.071203e+05
# 41     purchase cost  $/station  7.572294e+04
# 42     purchase cost  $/station  5.356013e+04
# 43     purchase cost  $/station  4.063182e+04
# 44     purchase cost  $/station  3.139732e+04
# 45     purchase cost  $/station  2.216281e+04
# 46     purchase cost  $/station  2.001886e+04
# 47     purchase cost  $/station  1.037874e+04
# 48     purchase cost  $/station  6.464153e+03
# 49     purchase cost  $/station  3.693802e+03
# 50     purchase cost  $/station  2.216281e+03
# 51     purchase cost  $/station  1.292831e+03
# 52     purchase cost  $/station  9.234505e+02
# 53     purchase cost  $/station  5.540703e+02
# 54     purchase cost  $/station  3.324422e+02
#
#        dehydr. reaction temperature (C) catalyst, pressure
# run #
# 1                             26.850000      Pd 4nm, 1 bar
# 2                             37.376316      Pd 4nm, 1 bar
# 3                             47.902632      Pd 4nm, 1 bar
# 4                             58.428947      Pd 4nm, 1 bar
# 5                             68.955263      Pd 4nm, 1 bar
# 6                             79.481579      Pd 4nm, 1 bar
# 7                             90.007895      Pd 4nm, 1 bar
# 8                            100.534211      Pd 4nm, 1 bar
# 9                            111.060526      Pd 4nm, 1 bar
# 10                            26.850000    Pd 4nm, 100 bar
# 11                            37.376316    Pd 4nm, 100 bar
# 12                            47.902632    Pd 4nm, 100 bar
# 13                            58.428947    Pd 4nm, 100 bar
# 14                            68.955263    Pd 4nm, 100 bar
# 15                            79.481579    Pd 4nm, 100 bar
# 16                            90.007895    Pd 4nm, 100 bar
# 17                           100.534211    Pd 4nm, 100 bar
# 18                           111.060526    Pd 4nm, 100 bar
# 19                            26.850000      Pt 4nm, 1 bar
# 20                            37.376316      Pt 4nm, 1 bar
# 21                            47.902632      Pt 4nm, 1 bar
# 22                            58.428947      Pt 4nm, 1 bar
# 23                            68.955263      Pt 4nm, 1 bar
# 24                            79.481579      Pt 4nm, 1 bar
# 25                            90.007895      Pt 4nm, 1 bar
# 26                           100.534211      Pt 4nm, 1 bar
# 27                           111.060526      Pt 4nm, 1 bar
# 28                            26.850000    Pt 4nm, 100 bar
# 29                            37.376316    Pt 4nm, 100 bar
# 30                            47.902632    Pt 4nm, 100 bar
# 31                            58.428947    Pt 4nm, 100 bar
# 32                            68.955263    Pt 4nm, 100 bar
# 33                            79.481579    Pt 4nm, 100 bar
# 34                            90.007895    Pt 4nm, 100 bar
# 35                           100.534211    Pt 4nm, 100 bar
# 36                           111.060526    Pt 4nm, 100 bar
# 37                            26.850000      Cu 4nm, 1 bar
# 38                            37.376316      Cu 4nm, 1 bar
# 39                            47.902632      Cu 4nm, 1 bar
# 40                            58.428947      Cu 4nm, 1 bar
# 41                            68.955263      Cu 4nm, 1 bar
# 42                            79.481579      Cu 4nm, 1 bar
# 43                            90.007895      Cu 4nm, 1 bar
# 44                           100.534211      Cu 4nm, 1 bar
# 45                           111.060526      Cu 4nm, 1 bar
# 46                            26.850000    Cu 4nm, 100 bar
# 47                            37.376316    Cu 4nm, 100 bar
# 48                            47.902632    Cu 4nm, 100 bar
# 49                            58.428947    Cu 4nm, 100 bar
# 50                            68.955263    Cu 4nm, 100 bar
# 51                            79.481579    Cu 4nm, 100 bar
# 52                            90.007895    Cu 4nm, 100 bar
# 53                           100.534211    Cu 4nm, 100 bar
# 54                           111.060526    Cu 4nm, 100 bar

# %%
# pivot catalyst cost dataframe
df_catal_cost_pivot = df_catal_cost_pres.pivot(
    columns = ['catalyst, pressure'],
    index = 'dehydr. reaction temperature (C)',
    values = '$/station'
    )

df_catal_cost_pivot
# Out:
# catalyst, pressure                Cu 4nm, 1 bar  Cu 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                         285089.392326     20018.856386
# 37.376316                         190065.689663     10378.738569
# 47.902632                         144058.273632      6464.153304
# 58.428947                         107120.254752      3693.801888
# 68.955263                          75722.938704      2216.281133
# 79.481579                          53560.127376      1292.830661
# 90.007895                          40631.820768       923.450472
# 100.534211                         31397.316048       554.070283
# 111.060526                         22162.811328       332.442170
#
# catalyst, pressure                Pd 4nm, 1 bar  Pd 4nm, 100 bar  \
# dehydr. reaction temperature (C)
# 26.850000                          33763.492117     35108.032420
# 37.376316                          14168.593602     14381.881594
# 47.902632                           6299.230635      6233.532895
# 58.428947                           2946.438666      2849.457081
# 68.955263                           1445.533171      1367.024268
# 79.481579                            738.953045       688.153167
# 90.007895                            392.580262       360.250157
# 100.534211                           217.073978       193.981046
# 111.060526                           124.702249       108.069768
#
# catalyst, pressure                Pt 4nm, 1 bar  Pt 4nm, 100 bar
# dehydr. reaction temperature (C)
# 26.850000                          7.501386e+06     7.501386e+06
# 37.376316                          2.271153e+06     2.271153e+06
# 47.902632                          8.707730e+05     8.707730e+05
# 58.428947                          3.958059e+05     3.285189e+05
# 68.955263                          1.781127e+05     1.385321e+05
# 79.481579                          8.311924e+04     5.937089e+04
# 90.007895                          3.958059e+04     2.731061e+04
# 100.534211                         2.058191e+04     1.306160e+04
# 111.060526                         1.187418e+04     6.728701e+03

# %% [markdown]
# ### 1D PLOT: (a) catalyst amount, (b) catalyst purchase cost, (c) total refueling station cost vs. dehydrogenation temperature and pressure for multiple catalysts

# %%
# define colors (and order) for catalysts
colors_catal = {
    'Pd 4nm' : '#7570b3',
    'Pt 4nm' : '#d95f02',
    'Cu 4nm' : '#1b9e77',
    }

# define line styles (and order) for pressures
linestyles_pres = {
    dehydr_pres_bar_to_plot[0] : 'solid',
    dehydr_pres_bar_to_plot[1] : 'dashed',
    }

# %%
# plot refueling station cost breakdown as function of 
# temperature at select pressures

# number of subplot rows and columns
nrows = 2
ncols = 2

# create subplots
fig, axes = plt.subplots(
    figsize=(7, 7),
    nrows=nrows,
    ncols=ncols, 
    layout='tight',
    dpi=600
    )

# fill subplots
for catal in colors_catal.keys():
    
    # color for each catalyst
    color = colors_catal[catal]

    for pres in linestyles_pres.keys():
        
        # column name to plot
        catal_pres = catal + ', ' + str(int(pres)) + ' bar'
        
        # line style for each pressure
        linestyle = linestyles_pres[pres]
    
        # plot catalyst amount (kg)
        df_catal_amt_kg_pivot[catal_pres].plot(
            ax=axes[0][0],
            linewidth=2.0,
            color=color,
            linestyle=linestyle,
            xticks=np.linspace(30, 90, 5),
            xlim=(30, 90),
            xlabel='Dehydrogenation temperature ($\\degree$C)',
            logy=True,
            ylabel='Catalyst amount (kg)',
            ylim=(1e-2, 1e4),
            yticks=np.logspace(-2, 4, 7)
        )

        # plot catalyst purchase cost ($)
        df_catal_cost_pivot[catal_pres].plot(
            ax=axes[1][0],
            linewidth=2.0,
            color=color,
            linestyle=linestyle,
            xticks=np.linspace(30, 90, 5),
            xlim=(30, 90),
            xlabel='Dehydrogenation temperature ($\\degree$C)',
            logy=True,
            ylabel='Catalyst purchase cost ($)',
            ylim=(1e2, 1e7),
            yticks=np.logspace(2, 7, 6)
            )
        
        # plot total refueling station cost ($/kg H2)
        df_stn_tot_pivot[catal_pres].plot(
            ax=axes[1][1],
            linewidth=2.0,
            color=color,
            linestyle=linestyle,
            xticks=np.linspace(30, 90, 5),
            xlim=(30, 90),
            xlabel='Dehydrogenation temperature ($\\degree$C)',
            ylabel='Levelized cost of hydrogen\n' + \
                '({:0.0f}\\$/kg'.format(output_dollar_year) + \
                ' ${H_2}$)',
            ylim=(0, 30)
            )

# plot catalyst unit cost ($/kg)
df_catal_unit_cost.plot.bar(
    ax=axes[0][1],
    y='dehydr. catalyst cost ($/kg)',
    color=colors_catal.values(),
    xlabel='Catalyst type',
    ylabel='Catalyst unit cost ($/kg)',
    ylim=(0, 4000),
    width=0.7,
    rot=0,
    )
axes[0][1].get_legend().remove()

# update subplot titles
axes[0][0].set_title(
    'Required catalyst amount',
    fontweight='bold',
    pad=15
)

axes[0][1].set_title(
    'Catalyst unit cost',
    fontweight='bold',
    pad=15
)

axes[1][0].set_title(
    'Catalyst purchase cost',
    fontweight='bold',
    pad=15
)

axes[1][1].set_title(
    'Total refueling station cost',
    fontweight='bold',
    pad=15
)

# add subplot numbering
text=[['A', 'B'], ['C', 'D']]
for i in range(nrows):
    for j in range(ncols):
        axes[i][j].annotate(
            text[i][j], 
            xy=(-0.2, 1.15), 
            xycoords='axes fraction', 
            annotation_clip=False,
            fontsize=18,
            fontweight='bold'
        )

# save plot
plt.savefig(
    'catalyst amout + cost + station cost vs T and p.svg',
    bbox_inches='tight'
    )

# show plot
plt.show()
